# %%
from Bio import SeqIO
import pandas as pd
import os

# %%
pattern = 'prodigal.gff'
samples = set()
for paths, dirs, files in os.walk('./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/'):
    for file in files:
        if pattern in file:
            sample = file.split('_prodigal.gff')[0]
            samples.add(sample)

# %%
def count_brex(file_path):
    """
    This function reads a CSV file at the given file path, extracts unique system numbers and system types 
    containing 'brex', and returns a list of system numbers and their corresponding system types.
    
    Parameters:
    file_path (str): The file path to the CSV file.
    
    Returns:
    tuple: Two lists - system_num_list containing unique system numbers, and system_type_list containing 
           corresponding system types with 'brex'.
    """
    df = pd.read_csv(file_path, header=None, skiprows=1, sep=',')
    
    unique_system_num_values = df[0].unique()
    unique_system_type_values = df[df[2].str.contains('brex')][2].unique()
    
    system_num_list = []
    system_type_list = []
    
    for val in unique_system_num_values:
        corresponding_val = df[(df[0] == val) & (df[2].str.contains('brex'))][2].values
        if len(corresponding_val) > 0:
            system_num_list.append(val)
            system_type_list.append(corresponding_val[0])
    
    return system_num_list, system_type_list

# %%
def process_csv_file(file_path, system_num, system_type):
    """
    This function processes a CSV file at the given file path based on the system number and system type provided.
    It extracts specific information such as the first and last numbers, corresponding names, and coordinates.

    Parameters:
    file_path (str): The file path to the CSV file.
    system_num (int): The system number to filter the data.
    system_type (str): The system type to match in the data.

    Returns:
    tuple: Contains first_number, last_number, name_contig_first, name_contig_last, start_coords, and last_coords.
    """
    regex = r"\b" + system_type + r"\b"
    system_num_str = str(system_num)
    df = pd.read_csv(file_path, header=None, sep = ',')
    first_brex_index = df[(df[0] == system_num_str) & (df[2].str.match(regex))].index[0]
    last_brex_index = df[(df[0] == system_num_str) & (df[2].str.match(regex))].index[-1]
    first_number = df.iloc[first_brex_index, 11]
    last_number = df.iloc[last_brex_index, 12]
    name_contig_first = df.iloc[first_brex_index, 1]
    name_contig_last = df.iloc[last_brex_index, 1]
    matching_rows = df[(df[0] == system_num_str) & (df[2].str.match(regex))]
    start_coords = matching_rows[11].tolist()
    last_coords = matching_rows[12].tolist()
    return first_number, last_number, name_contig_first, name_contig_last, start_coords, last_coords

# %%
def find_closest_rows(file_path, first_number, last_number, name_contig_first, name_contig_last):
    """
    This function finds the closest rows in a file based on specified criteria.

    Parameters:
    file_path (str): The file path to the file.
    first_number (int): The first number for comparison.
    last_number (int): The last number for comparison.
    name_contig_first (str): The name for the first comparison.
    name_contig_last (str): The name for the last comparison.

    Returns:
    tuple: Contains closest_first, closest_last, coord_first, and coord_last.
    """
    first_number = int(first_number)
    last_number = int(last_number)
    first_number -= 10000
    last_number += 10000
    closest_first = None
    closest_last = None
    min_diff_first = float('inf')
    min_diff_last = float('inf')
    if first_number - 10000 < 0:
        first_number = 0

    with open(file_path, 'r') as file:
        line_number = 0
        for line in file:
            cols = line.strip().split('\t')
            try:
                col4 = int(cols[3])
                col5 = int(cols[4])
                col1 = cols[0]
                diff_first = abs(first_number - col4)
                diff_last = abs(last_number - col5)

                if col4 >= first_number and diff_first < min_diff_first and col1 == name_contig_first:
                    closest_first = line_number
                    min_diff_first = diff_first
                    coord_first = col4

                if col5 <= last_number and diff_last < min_diff_last and col1 == name_contig_last:
                    closest_last = line_number
                    min_diff_last = diff_last
                    coord_last = col5
            except ValueError:
                pass

            line_number += 1
    

    return closest_first, closest_last, coord_first, coord_last

# %%
def write_flank_gff(file_path_to_gff, name_assemb, name_contig_first, num, type, closest_first, closest_last):
    """
    This function writes specific lines from a GFF file to a new GFF file based on the provided parameters.

    Parameters:
    file_path_to_gff (str): The file path to the GFF file.
    name_assemb (str): The name of the assembly.
    name_contig_first (str): The name of the first contig.
    num (int): A number for identification.
    type (str): The type for identification.
    closest_first (int): The index of the closest first line.
    closest_last (int): The index of the closest last line.

    Returns:
    str: The file path to the newly created GFF file containing the selected lines.
    """
    name_output_gff = './data_for_padloc/'+ name_assemb + '_' + type + '_' + str(num) + '_' + name_contig_first + '_reg.gff'
    closest_last += 1 
    lines_to_read = range(closest_first, closest_last)  # интересующие нас строки
    result = [line for i, line in enumerate(open(file_path_to_gff)) if i in lines_to_read]

    with open(name_output_gff, 'a') as file:
        for string in result:
            file.write(string)
    return name_output_gff# вот искомые строки!

# %%
def check_genes_positions(input_file_path, first_gene, last_gene, start_coords, last_coords):
    """
    This function checks gene positions in a GFF file based on specified criteria and updates a new column accordingly.

    Parameters:
    input_file_path (str): The file path to the input GFF file.
    first_gene (int): The position of the first gene.
    last_gene (int): The position of the last gene.
    start_coords (list): List of start coordinates.
    last_coords (list): List of last coordinates.

    Returns:
    None
    """
    df = pd.read_csv(input_file_path, header=None, sep='\t')
    df['new_col'] = 'inner'
    start_coords = [int(coord) for coord in start_coords]
    last_coords = [int(coord) for coord in last_coords]
    strand_value = ''
    brex_found = False
    for index, row in df.iterrows():
        if row[3] in start_coords and row[4] in last_coords:
            df.at[index, 'new_col'] = 'brex'
            strand_value = row[6]
            brex_found = True
        else:
            if row[3] >= int(first_gene) and row[4] <= int(last_gene):
                df.at[index, 'new_col'] = 'inner'
            elif row[3] < int(first_gene) and row[4] < int(first_gene):
                if strand_value == '+':
                    df.at[index, 'new_col'] = 'upstream'
                else:
                    df.at[index, 'new_col'] = 'downstream'
            elif row[3] > int(last_gene) and row[4] > int(last_gene):
                if strand_value == '+':
                    df.at[index, 'new_col'] = 'downstream'
                else:
                    df.at[index, 'new_col'] = 'upstream'

    output_file_path = input_file_path.replace('.gff', '_positions.gff')
    df.to_csv(output_file_path, sep='\t', header=False, index=False)

# %%
def extract_sequences(input_file, output_file, start_line, end_line, name_assemb, name_contig_first, num, type):
    """
    Extracts sequences from a FASTA file based on the specified start and end lines.

    Parameters:
    input_file (str): The input FASTA file path.
    output_file (str): The output file path to write the extracted sequences.
    start_line (int): The start line for extraction.
    end_line (int): The end line for extraction.
    name_assemb (str): The name of the assembly.
    name_contig_first (str): The name of the first contig.
    num (int): A number for identification.
    type (str): The type for identification.

    Returns:
    None
    """
    sequences = []
    name_output_faa = './data_for_padloc/'+ name_assemb + '_' + type + '_' + str(num) + '_' + name_contig_first + '_reg.faa'
    
    with open(input_file, 'r') as file:
        for i, record in enumerate(SeqIO.parse(file, 'fasta')):
            if start_line <= i <= end_line:
                sequences.append(record)

    with open(output_file, 'a') as out_file:
        SeqIO.write(sequences, out_file, 'fasta')
    
    with open(name_output_faa, 'a') as file:
        SeqIO.write(sequences, file, 'fasta')

# %%
def extract_coord_loc(name_assemb, num, type, name_contig_first, name_contig_last, first_gene, last_gene, closest_first, closest_last, coord_first, coord_last, coor_table):
    """
    Writes coordinate location information to a coordinate table.

    Parameters:
    name_assemb (str): The name of the assembly.
    num (int): A number for identification.
    type (str): The type for identification.
    name_contig_first (str): The name of the first contig.
    name_contig_last (str): The name of the last contig.
    first_gene (int): The position of the first gene.
    last_gene (int): The position of the last gene.
    closest_first (int): The index of the closest first line.
    closest_last (int): The index of the closest last line.
    coord_first (int): The coordinate of the first location.
    coord_last (int): The coordinate of the last location.
    coor_table (str): The file path to the coordinate table.

    Returns:
    None
    """
    with open(coor_table, 'a') as file:
        file.write(f'{name_assemb}\t{type}\t{num}\t{name_contig_first}\t{name_contig_last}\t{first_gene}\t{last_gene}\t{closest_first}\t{closest_last}\t{coord_first}\t{coord_last}\n')

# %%
def extract_faa(input_dir_path, sample_names, output_file_faa, coor_table):
    """
    Extracts information and sequences from multiple files in a directory and writes them to output files.

    Parameters:
    input_dir_path (str): The path to the input directory.
    sample_names (list): List of sample names.
    output_file_faa (str): The output file path for writing the extracted sequences.
    coor_table (str): The file path to the coordinate table.

    Returns:
    list: List of files with errors encountered during processing.
    """
    file_num = 1
    errors_csv = []
    for file in sample_names:
        file_path_to_csv = input_dir_path + file + '_padloc.csv'
        name_assemb = file[0:15]
        print(file_path_to_csv)
        system_num_list, system_type_list = count_brex(file_path_to_csv)
        if len(system_type_list) == 0:
            errors_csv.append(file)
            print(f'Oops, there is no brex in file {file_num}')
        else:
            for num, type in zip(system_num_list, system_type_list):
                first_gene, last_gene, name_contig_first, name_contig_last, start_coords, last_coords = process_csv_file(file_path_to_csv, num, type)
                if name_contig_first != name_contig_last:
                    errors_csv.append(file)
                    print(f'Brex system {file_num} is broken. Two contigs')
                    break
                file_path_to_gff = input_dir_path + file + '_prodigal.gff'
                closest_first, closest_last, coord_first, coord_last = find_closest_rows(file_path_to_gff, first_gene, last_gene, name_contig_first, name_contig_last)
                file_path_to_faa = input_dir_path + file + '_prodigal.faa'
                input_file_path_to_flank_gff = write_flank_gff(file_path_to_gff, name_assemb, name_contig_first, num, type, closest_first, closest_last)
                check_genes_positions(input_file_path_to_flank_gff, first_gene, last_gene, start_coords, last_coords)
                extract_sequences(file_path_to_faa, output_file_faa, closest_first, closest_last, name_assemb, name_contig_first, num, type)
                extract_coord_loc(name_assemb, num, type, name_contig_first, name_contig_last, first_gene, last_gene, closest_first, closest_last, coord_first, coord_last, coor_table)
                print(f'I am done with file number {file_num}')
        file_num += 1
    return errors_csv

# %%
output_file = "flank_4.fasta"
coor_table = "coordinates_types_2.txt"
input_dir_path = './2024-02-26_padloc_hmm_custom/padloc_hmm_custom/'
error = extract_faa(input_dir_path, samples, output_file, coor_table)
# Out:
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013378175.1_ASM1337817v1_genomic_padloc.csv
# I am done with file number 1
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003721175.2_ASM372117v2_genomic_padloc.csv
# Oops, there is no brex in file 2
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000179395.2_ASM17939v2_genomic_padloc.csv
# I am done with file number 3
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003812085.1_ASM381208v1_genomic_padloc.csv
# I am done with file number 4
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009740265.1_ASM974026v1_genomic_padloc.csv
# I am done with file number 5
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900475685.1_46463_B01_genomic_padloc.csv
# I am done with file number 6
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013376495.1_ASM1337649v1_genomic_padloc.csv
# I am done with file number 7
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015278095.1_ASM1527809v1_genomic_padloc.csv
# I am done with file number 8
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003177235.1_ASM317723v1_genomic_padloc.csv
# I am done with file number 9
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003336365.1_ASM333636v1_genomic_padloc.csv
# Oops, there is no brex in file 10
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019797825.1_ASM1979782v1_genomic_padloc.csv
# Oops, there is no brex in file 11
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009498295.1_ASM949829v1_genomic_padloc.csv
# I am done with file number 12
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004124035.2_ASM412403v2_genomic_padloc.csv
# I am done with file number 13
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017134335.1_ASM1713433v1_genomic_padloc.csv
# I am done with file number 14
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000304355.2_Mb_MS2_genomic_padloc.csv
# I am done with file number 15
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014621695.1_ASM1462169v1_genomic_padloc.csv
# Oops, there is no brex in file 16
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000284035.1_ASM28403v1_genomic_padloc.csv
# I am done with file number 17
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000020025.1_ASM2002v1_genomic_padloc.csv
# I am done with file number 18
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004138605.1_ASM413860v1_genomic_padloc.csv
# Oops, there is no brex in file 19
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011045875.1_ASM1104587v1_genomic_padloc.csv
# I am done with file number 20
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000015025.1_ASM1502v1_genomic_padloc.csv
# I am done with file number 21
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000478825.2_ASM47882v2_genomic_padloc.csv
# Oops, there is no brex in file 22
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_006517215.1_ASM651721v1_genomic_padloc.csv
# I am done with file number 23
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000255295.1_ASM25529v1_genomic_padloc.csv
# I am done with file number 24
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002211505.1_ASM221150v1_genomic_padloc.csv
# Oops, there is no brex in file 25
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016458785.1_ASM1645878v1_genomic_padloc.csv
# I am done with file number 26
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009799825.1_ASM979982v1_genomic_padloc.csv
# I am done with file number 27
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022453565.1_ASM2245356v1_genomic_padloc.csv
# I am done with file number 28
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018408455.1_ASM1840845v1_genomic_padloc.csv
# Oops, there is no brex in file 29
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004114755.1_ASM411475v1_genomic_padloc.csv
# Oops, there is no brex in file 30
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009936255.1_ASM993625v1_genomic_padloc.csv
# Oops, there is no brex in file 31
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011046025.1_ASM1104602v1_genomic_padloc.csv
# I am done with file number 32
# I am done with file number 32
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017183935.1_ASM1718393v1_genomic_padloc.csv
# I am done with file number 33
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007990425.1_ASM799042v1_genomic_padloc.csv
# Oops, there is no brex in file 34
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017948305.1_ASM1794830v1_genomic_padloc.csv
# Oops, there is no brex in file 35
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900639575.1_E8014_hybrid_assembly_genomic_padloc.csv
# I am done with file number 36
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016025415.2_ASM1602541v2_genomic_padloc.csv
# I am done with file number 37
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003261575.2_ASM326157v2_genomic_padloc.csv
# I am done with file number 38
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002334685.1_ASM233468v1_genomic_padloc.csv
# I am done with file number 39
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013347285.1_ASM1334728v1_genomic_padloc.csv
# I am done with file number 40
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001007995.1_ASM100799v1_genomic_padloc.csv
# I am done with file number 41
# I am done with file number 41
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023370095.1_ASM2337009v1_genomic_padloc.csv
# I am done with file number 42
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001983995.1_ASM198399v1_genomic_padloc.csv
# I am done with file number 43
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017134355.1_ASM1713435v1_genomic_padloc.csv
# I am done with file number 44
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007747995.1_ASM774799v1_genomic_padloc.csv
# I am done with file number 45
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900520395.1_ASM90052039v1_genomic_padloc.csv
# I am done with file number 46
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023101025.1_ASM2310102v1_genomic_padloc.csv
# I am done with file number 47
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004101645.1_ASM410164v1_genomic_padloc.csv
# I am done with file number 48
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_005280435.1_ASM528043v1_genomic_padloc.csv
# I am done with file number 49
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900324455.1_48853_A02_genomic_padloc.csv
# I am done with file number 50
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003053755.1_ASM305375v1_genomic_padloc.csv
# I am done with file number 51
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002787395.1_ASM278739v1_genomic_padloc.csv
# I am done with file number 52
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016861485.1_ASM1686148v1_genomic_padloc.csv
# Oops, there is no brex in file 53
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019968705.1_ASM1996870v1_genomic_padloc.csv
# Oops, there is no brex in file 54
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003665375.1_ASM366537v1_genomic_padloc.csv
# I am done with file number 55
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003176855.1_ASM317685v1_genomic_padloc.csv
# I am done with file number 56
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013488005.1_ASM1348800v1_genomic_padloc.csv
# Oops, there is no brex in file 57
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016458825.1_ASM1645882v1_genomic_padloc.csv
# I am done with file number 58
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016313185.1_ASM1631318v1_genomic_padloc.csv
# I am done with file number 59
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001027025.1_ASM102702v1_genomic_padloc.csv
# I am done with file number 60
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002165255.2_ASM216525v2_genomic_padloc.csv
# I am done with file number 61
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002205775.2_ASM220577v2_genomic_padloc.csv
# Oops, there is no brex in file 62
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013624375.1_ASM1362437v1_genomic_padloc.csv
# I am done with file number 63
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023809705.1_ASM2380970v1_genomic_padloc.csv
# I am done with file number 64
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016126935.1_ASM1612693v1_genomic_padloc.csv
# I am done with file number 65
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021655055.1_ASM2165505v1_genomic_padloc.csv
# I am done with file number 66
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_008329645.1_ASM832964v1_genomic_padloc.csv
# I am done with file number 67
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017743195.1_ASM1774319v1_genomic_padloc.csv
# I am done with file number 68
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016888945.1_ASM1688894v1_genomic_padloc.csv
# I am done with file number 69
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017742855.1_ASM1774285v1_genomic_padloc.csv
# I am done with file number 70
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000013385.1_ASM1338v1_genomic_padloc.csv
# I am done with file number 71
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001267275.1_ASM126727v1_genomic_padloc.csv
# Oops, there is no brex in file 72
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002984285.1_ASM298428v1_genomic_padloc.csv
# I am done with file number 73
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019856495.1_ASM1985649v1_genomic_padloc.csv
# Oops, there is no brex in file 74
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_005849145.1_ASM584914v1_genomic_padloc.csv
# Oops, there is no brex in file 75
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002208765.2_ASM220876v2_genomic_padloc.csv
# Oops, there is no brex in file 76
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001482365.1_ASM148236v1_genomic_padloc.csv
# I am done with file number 77
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001998865.1_ASM199886v1_genomic_padloc.csv
# I am done with file number 78
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002105775.1_ASM210577v1_genomic_padloc.csv
# I am done with file number 79
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020519665.1_ASM2051966v1_genomic_padloc.csv
# I am done with file number 80
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001663735.1_ASM166373v1_genomic_padloc.csv
# Oops, there is no brex in file 81
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009856645.1_ASM985664v1_genomic_padloc.csv
# I am done with file number 82
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021266265.1_ASM2126626v1_genomic_padloc.csv
# I am done with file number 83
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000196475.1_ASM19647v1_genomic_padloc.csv
# Oops, there is no brex in file 84
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003812065.1_ASM381206v1_genomic_padloc.csv
# I am done with file number 85
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019787625.1_ASM1978762v1_genomic_padloc.csv
# I am done with file number 86
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002355655.1_ASM235565v1_genomic_padloc.csv
# Oops, there is no brex in file 87
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023330885.1_ASM2333088v1_genomic_padloc.csv
# I am done with file number 88
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022343685.1_ASM2234368v1_genomic_padloc.csv
# Oops, there is no brex in file 89
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003111665.1_ASM311166v1_genomic_padloc.csv
# I am done with file number 90
# I am done with file number 90
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017377355.1_ASM1737735v1_genomic_padloc.csv
# I am done with file number 91
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022493455.1_ASM2249345v1_genomic_padloc.csv
# I am done with file number 92
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000504565.1_ASM50456v2_genomic_padloc.csv
# I am done with file number 93
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015679285.1_ASM1567928v1_genomic_padloc.csv
# I am done with file number 94
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001854245.1_ASM185424v1_genomic_padloc.csv
# I am done with file number 95
# I am done with file number 95
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003952825.1_ASM395282v1_genomic_padloc.csv
# I am done with file number 96
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001886355.1_ASM188635v1_genomic_padloc.csv
# Oops, there is no brex in file 97
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016772275.1_ASM1677227v1_genomic_padloc.csv
# I am done with file number 98
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002007845.1_ASM200784v1_genomic_padloc.csv
# I am done with file number 99
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020084865.1_ASM2008486v1_genomic_padloc.csv
# I am done with file number 100
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900639705.1_E9101_hybrid_assembly_genomic_padloc.csv
# I am done with file number 101
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009763825.1_ASM976382v1_genomic_padloc.csv
# I am done with file number 102
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004345025.1_ASM434502v1_genomic_padloc.csv
# I am done with file number 103
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004792475.1_ASM479247v1_genomic_padloc.csv
# I am done with file number 104
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000831585.1_ASM83158v1_genomic_padloc.csv
# I am done with file number 105
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020002285.1_ASM2000228v1_genomic_padloc.csv
# I am done with file number 106
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003574835.2_ASM357483v2_genomic_padloc.csv
# Oops, there is no brex in file 107
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009676445.1_ASM967644v1_genomic_padloc.csv
# I am done with file number 108
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023922005.1_ASM2392200v1_genomic_padloc.csv
# I am done with file number 109
# I am done with file number 109
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003856635.1_ASM385663v1_genomic_padloc.csv
# I am done with file number 110
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001705365.1_ASM170536v1_genomic_padloc.csv
# I am done with file number 111
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013357405.1_ASM1335740v1_genomic_padloc.csv
# I am done with file number 112
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022354505.1_ASM2235450v1_genomic_padloc.csv
# I am done with file number 113
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000183405.1_ASM18340v1_genomic_padloc.csv
# I am done with file number 114
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000233715.2_ASM23371v3_genomic_padloc.csv
# Oops, there is no brex in file 115
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002208885.2_ASM220888v2_genomic_padloc.csv
# I am done with file number 116
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018141145.1_ASM1814114v1_genomic_padloc.csv
# I am done with file number 117
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020827555.1_ASM2082755v1_genomic_padloc.csv
# I am done with file number 118
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022343245.1_ASM2234324v1_genomic_padloc.csv
# I am done with file number 119
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023022965.1_ASM2302296v1_genomic_padloc.csv
# I am done with file number 120
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023700225.1_ASM2370022v1_genomic_padloc.csv
# I am done with file number 121
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020541025.1_ASM2054102v1_genomic_padloc.csv
# Oops, there is no brex in file 122
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023330845.1_ASM2333084v1_genomic_padloc.csv
# I am done with file number 123
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018884425.1_ASM1888442v1_genomic_padloc.csv
# I am done with file number 124
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013402815.2_ASM1340281v2_genomic_padloc.csv
# I am done with file number 125
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001682385.1_ASM168238v1_genomic_padloc.csv
# I am done with file number 126
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020628455.1_ASM2062845v1_genomic_padloc.csv
# Oops, there is no brex in file 127
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_012051385.1_ASM1205138v1_genomic_padloc.csv
# I am done with file number 128
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001721805.1_ASM172180v1_genomic_padloc.csv
# Oops, there is no brex in file 129
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000237085.1_ASM23708v1_genomic_padloc.csv
# I am done with file number 130
# I am done with file number 130
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016615815.1_ASM1661581v1_genomic_padloc.csv
# I am done with file number 131
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001901365.1_ASM190136v1_genomic_padloc.csv
# I am done with file number 132
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003955865.1_ASM395586v1_genomic_padloc.csv
# Oops, there is no brex in file 133
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020641015.1_ASM2064101v1_genomic_padloc.csv
# I am done with file number 134
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013733395.1_ASM1373339v1_genomic_padloc.csv
# I am done with file number 135
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013112015.1_ASM1311201v1_genomic_padloc.csv
# Oops, there is no brex in file 136
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003181075.1_ASM318107v1_genomic_padloc.csv
# I am done with file number 137
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022919135.1_ASM2291913v1_genomic_padloc.csv
# I am done with file number 138
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007113525.2_ASM711352v2_genomic_padloc.csv
# Oops, there is no brex in file 139
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018326605.1_ASM1832660v1_genomic_padloc.csv
# I am done with file number 140
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013457875.1_ASM1345787v1_genomic_padloc.csv
# I am done with file number 141
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003288275.1_ASM328827v1_genomic_padloc.csv
# I am done with file number 142
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003950255.1_ASM395025v1_genomic_padloc.csv
# I am done with file number 143
# I am done with file number 143
# I am done with file number 143
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013114975.1_ASM1311497v1_genomic_padloc.csv
# I am done with file number 144
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001953175.1_ASM195317v1_genomic_padloc.csv
# I am done with file number 145
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000725405.1_ASM72540v1_genomic_padloc.csv
# I am done with file number 146
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003428395.1_ASM342839v1_genomic_padloc.csv
# Oops, there is no brex in file 147
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020405225.1_ASM2040522v1_genomic_padloc.csv
# I am done with file number 148
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000012985.1_ASM1298v1_genomic_padloc.csv
# I am done with file number 149
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_012272955.1_ASM1227295v1_genomic_padloc.csv
# I am done with file number 150
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001020725.2_ASM102072v2_genomic_padloc.csv
# I am done with file number 151
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003491245.1_ASM349124v1_genomic_padloc.csv
# Oops, there is no brex in file 152
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021498045.1_ASM2149804v1_genomic_padloc.csv
# I am done with file number 153
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003597635.1_ASM359763v1_genomic_padloc.csv
# Oops, there is no brex in file 154
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020783475.1_ASM2078347v1_genomic_padloc.csv
# I am done with file number 155
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021266365.1_ASM2126636v1_genomic_padloc.csv
# I am done with file number 156
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_008041895.1_ASM804189v1_genomic_padloc.csv
# I am done with file number 157
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011068365.1_ASM1106836v1_genomic_padloc.csv
# I am done with file number 158
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013635755.1_ASM1363575v1_genomic_padloc.csv
# I am done with file number 159
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014843115.1_ASM1484311v1_genomic_padloc.csv
# I am done with file number 160
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009936235.1_ASM993623v1_genomic_padloc.csv
# I am done with file number 161
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900232105.1_Kuenenia_stuttgartiensis_MBR1_genomic_padloc.csv
# I am done with file number 162
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016117655.1_ASM1611765v1_genomic_padloc.csv
# Oops, there is no brex in file 163
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016452165.1_ASM1645216v1_genomic_padloc.csv
# I am done with file number 164
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017724155.1_ASM1772415v1_genomic_padloc.csv
# I am done with file number 165
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003932995.1_ASM393299v1_genomic_padloc.csv
# I am done with file number 166
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014295275.1_ASM1429527v1_genomic_padloc.csv
# I am done with file number 167
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002903405.1_ASM290340v1_genomic_padloc.csv
# Oops, there is no brex in file 168
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016415485.1_ASM1641548v1_genomic_padloc.csv
# I am done with file number 169
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013735155.1_ASM1373515v1_genomic_padloc.csv
# I am done with file number 170
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009796745.1_ASM979674v1_genomic_padloc.csv
# Oops, there is no brex in file 171
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001806305.1_ASM180630v1_genomic_padloc.csv
# I am done with file number 172
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016616645.1_ASM1661664v1_genomic_padloc.csv
# I am done with file number 173
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009017315.1_ASM901731v1_genomic_padloc.csv
# I am done with file number 174
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023101285.1_ASM2310128v1_genomic_padloc.csv
# I am done with file number 175
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020172745.1_ASM2017274v1_genomic_padloc.csv
# I am done with file number 176
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019968605.1_ASM1996860v1_genomic_padloc.csv
# Oops, there is no brex in file 177
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900095135.1_M36_genomic_padloc.csv
# I am done with file number 178
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015476095.1_ASM1547609v1_genomic_padloc.csv
# I am done with file number 179
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013341295.1_ASM1334129v1_genomic_padloc.csv
# I am done with file number 180
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013416105.1_ASM1341610v1_genomic_padloc.csv
# I am done with file number 181
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009296025.1_ASM929602v1_genomic_padloc.csv
# I am done with file number 182
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020535185.1_ASM2053518v1_genomic_padloc.csv
# I am done with file number 183
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001618365.1_ASM161836v1_genomic_padloc.csv
# I am done with file number 184
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002142575.1_ASM214257v1_genomic_padloc.csv
# I am done with file number 185
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_905337805.2_AN2353v1_cp_genomic_padloc.csv
# I am done with file number 186
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014904235.2_ASM1490423v2_genomic_padloc.csv
# Oops, there is no brex in file 187
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000270245.1_ASM27024v1_genomic_padloc.csv
# I am done with file number 188
# I am done with file number 188
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_024022895.1_ASM2402289v1_genomic_padloc.csv
# I am done with file number 189
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002290025.1_ASM229002v1_genomic_padloc.csv
# Oops, there is no brex in file 190
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017903455.1_ASM1790345v1_genomic_padloc.csv
# I am done with file number 191
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016903075.1_ASM1690307v1_genomic_padloc.csv
# I am done with file number 192
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003353455.1_ASM335345v1_genomic_padloc.csv
# I am done with file number 193
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023277745.1_ASM2327774v1_genomic_padloc.csv
# I am done with file number 194
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004328885.1_ASM432888v1_genomic_padloc.csv
# I am done with file number 195
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002734145.1_ASM273414v1_genomic_padloc.csv
# I am done with file number 196
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900184385.1_STMU2UK_genomic_padloc.csv
# I am done with file number 197
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003018215.1_ASM301821v1_genomic_padloc.csv
# I am done with file number 198
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019973655.1_ASM1997365v1_genomic_padloc.csv
# Oops, there is no brex in file 199
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004324025.2_ASM432402v2_genomic_padloc.csv
# I am done with file number 200
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009846525.1_ASM984652v1_genomic_padloc.csv
# I am done with file number 201
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011769825.1_ASM1176982v1_genomic_padloc.csv
# I am done with file number 202
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001689125.2_ASM168912v2_genomic_padloc.csv
# Oops, there is no brex in file 203
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002180135.1_ASM218013v1_genomic_padloc.csv
# I am done with file number 204
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022819265.1_ASM2281926v1_genomic_padloc.csv
# I am done with file number 205
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015244315.1_ASM1524431v1_genomic_padloc.csv
# Oops, there is no brex in file 206
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000023945.1_ASM2394v1_genomic_padloc.csv
# Oops, there is no brex in file 207
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016917835.2_ASM1691783v3_genomic_padloc.csv
# I am done with file number 208
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016454605.1_ASM1645460v1_genomic_padloc.csv
# I am done with file number 209
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013781985.1_ASM1378198v1_genomic_padloc.csv
# Oops, there is no brex in file 210
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009892345.1_ASM989234v1_genomic_padloc.csv
# I am done with file number 211
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002803925.1_ASM280392v1_genomic_padloc.csv
# I am done with file number 212
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011149675.1_ASM1114967v1_genomic_padloc.csv
# I am done with file number 213
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016906065.1_ASM1690606v1_genomic_padloc.csv
# I am done with file number 214
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003963515.1_ASM396351v1_genomic_padloc.csv
# I am done with file number 215
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003058365.1_ASM305836v1_genomic_padloc.csv
# I am done with file number 216
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021398615.1_ASM2139861v1_genomic_padloc.csv
# Oops, there is no brex in file 217
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004124055.2_ASM412405v2_genomic_padloc.csv
# I am done with file number 218
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013393825.1_ASM1339382v1_genomic_padloc.csv
# I am done with file number 219
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001685355.1_ASM168535v1_genomic_padloc.csv
# I am done with file number 220
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021399175.1_ASM2139917v1_genomic_padloc.csv
# I am done with file number 221
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023221575.1_ASM2322157v1_genomic_padloc.csv
# I am done with file number 222
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016903055.1_ASM1690305v1_genomic_padloc.csv
# Oops, there is no brex in file 223
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016454525.1_ASM1645452v1_genomic_padloc.csv
# I am done with file number 224
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014084125.1_ASM1408412v1_genomic_padloc.csv
# I am done with file number 225
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_904863245.1_INF355_genomic_padloc.csv
# I am done with file number 226
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022812045.1_ASM2281204v1_genomic_padloc.csv
# Oops, there is no brex in file 227
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015034605.1_ASM1503460v1_genomic_padloc.csv
# I am done with file number 228
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000189775.2_ASM18977v3_genomic_padloc.csv
# I am done with file number 229
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023657995.1_ASM2365799v1_genomic_padloc.csv
# I am done with file number 230
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900682675.2_P_marincola_YSy11_v2_genomic_padloc.csv
# I am done with file number 231
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011045355.1_ASM1104535v1_genomic_padloc.csv
# Oops, there is no brex in file 232
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001729225.1_ASM172922v1_genomic_padloc.csv
# I am done with file number 233
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_006151905.1_ASM615190v1_genomic_padloc.csv
# I am done with file number 234
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900639495.1_E7471_hybrid_assembly_genomic_padloc.csv
# I am done with file number 235
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018847315.1_ASM1884731v1_genomic_padloc.csv
# I am done with file number 236
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004208635.1_ASM420863v1_genomic_padloc.csv
# I am done with file number 237
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020149665.1_ASM2014966v1_genomic_padloc.csv
# I am done with file number 238
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002568625.1_ASM256862v1_genomic_padloc.csv
# I am done with file number 239
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002354895.1_ASM235489v1_genomic_padloc.csv
# I am done with file number 240
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017724215.1_ASM1772421v1_genomic_padloc.csv
# I am done with file number 241
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000014725.1_ASM1472v1_genomic_padloc.csv
# I am done with file number 242
# I am done with file number 242
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001901315.1_ASM190131v1_genomic_padloc.csv
# I am done with file number 243
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004014695.1_ASM401469v1_genomic_padloc.csv
# I am done with file number 244
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013394065.1_ASM1339406v1_genomic_padloc.csv
# I am done with file number 245
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019428525.1_ASM1942852v1_genomic_padloc.csv
# I am done with file number 246
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018847295.1_ASM1884729v1_genomic_padloc.csv
# I am done with file number 247
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000092205.1_ASM9220v1_genomic_padloc.csv
# I am done with file number 248
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_008931405.1_ASM893140v1_genomic_padloc.csv
# I am done with file number 249
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002813775.1_ASM281377v1_genomic_padloc.csv
# I am done with file number 250
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900636455.1_42166_D01_genomic_padloc.csv
# I am done with file number 251
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023330805.1_ASM2333080v1_genomic_padloc.csv
# I am done with file number 252
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000242455.2_ASM24245v3_genomic_padloc.csv
# I am done with file number 253
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002156845.1_ASM215684v1_genomic_padloc.csv
# I am done with file number 254
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023702145.1_ASM2370214v1_genomic_padloc.csv
# Oops, there is no brex in file 255
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000307105.1_ASM30710v1_genomic_padloc.csv
# I am done with file number 256
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_902459535.1_Paraburkholderia_sp_Msb3_genomic_padloc.csv
# I am done with file number 257
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000012825.1_ASM1282v1_genomic_padloc.csv
# Oops, there is no brex in file 258
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_902388175.1_UHGG_MGYG-HGUT-02539_genomic_padloc.csv
# I am done with file number 259
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022699605.1_ASM2269960v1_genomic_padloc.csv
# Oops, there is no brex in file 260
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001610995.1_ASM161099v1_genomic_padloc.csv
# Oops, there is no brex in file 261
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011492925.1_ASM1149292v1_genomic_padloc.csv
# I am done with file number 262
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000144625.1_ASM14462v1_genomic_padloc.csv
# I am done with file number 263
# I am done with file number 263
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002028285.1_ASM202828v1_genomic_padloc.csv
# I am done with file number 264
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022936485.1_ASM2293648v1_genomic_padloc.csv
# I am done with file number 265
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020810655.1_ASM2081065v1_genomic_padloc.csv
# I am done with file number 266
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003864015.1_ASM386401v1_genomic_padloc.csv
# I am done with file number 267
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003312875.1_ASM331287v1_genomic_padloc.csv
# I am done with file number 268
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_008704425.1_ASM870442v1_genomic_padloc.csv
# Oops, there is no brex in file 269
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003072585.2_ASM307258v2_genomic_padloc.csv
# I am done with file number 270
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014337155.1_ASM1433715v1_genomic_padloc.csv
# I am done with file number 271
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018310435.1_ASM1831043v1_genomic_padloc.csv
# I am done with file number 272
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003856735.1_ASM385673v1_genomic_padloc.csv
# I am done with file number 273
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004101545.1_ASM410154v1_genomic_padloc.csv
# Oops, there is no brex in file 274
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020097475.1_ASM2009747v1_genomic_padloc.csv
# I am done with file number 275
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013610655.1_ASM1361065v1_genomic_padloc.csv
# I am done with file number 276
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003122365.1_ASM312236v1_genomic_padloc.csv
# Oops, there is no brex in file 277
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_012052225.1_ASM1205222v1_genomic_padloc.csv
# I am done with file number 278
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016607565.1_ASM1660756v1_genomic_padloc.csv
# I am done with file number 279
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018289355.1_ASM1828935v1_genomic_padloc.csv
# I am done with file number 280
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018326265.1_ASM1832626v1_genomic_padloc.csv
# Oops, there is no brex in file 281
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022631175.1_ASM2263117v1_genomic_padloc.csv
# Oops, there is no brex in file 282
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002209385.1_ASM220938v1_genomic_padloc.csv
# I am done with file number 283
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019443785.1_ASM1944378v1_genomic_padloc.csv
# I am done with file number 284
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002441955.1_ASM244195v1_genomic_padloc.csv
# I am done with file number 285
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001932555.1_ASM193255v1_genomic_padloc.csv
# I am done with file number 286
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007113505.2_ASM711350v2_genomic_padloc.csv
# Oops, there is no brex in file 287
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002953335.1_ASM295333v1_genomic_padloc.csv
# I am done with file number 288
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003967095.1_ASM396709v1_genomic_padloc.csv
# I am done with file number 289
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023159135.1_ASM2315913v1_genomic_padloc.csv
# I am done with file number 290
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000019085.1_ASM1908v1_genomic_padloc.csv
# I am done with file number 291
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_008386315.1_ASM838631v1_genomic_padloc.csv
# I am done with file number 292
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017724115.1_ASM1772411v1_genomic_padloc.csv
# I am done with file number 293
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016415445.1_ASM1641544v1_genomic_padloc.csv
# I am done with file number 294
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000010325.1_ASM1032v1_genomic_padloc.csv
# Oops, there is no brex in file 295
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_005537375.1_ASM553737v1_genomic_padloc.csv
# I am done with file number 296
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014898175.1_ASM1489817v1_genomic_padloc.csv
# I am done with file number 297
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_005484805.1_ASM548480v1_genomic_padloc.csv
# I am done with file number 298
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002085605.1_ASM208560v1_genomic_padloc.csv
# I am done with file number 299
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015840525.1_ASM1584052v1_genomic_padloc.csv
# I am done with file number 300
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000327045.1_ASM32704v1_genomic_padloc.csv
# I am done with file number 301
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002056065.1_ASM205606v1_genomic_padloc.csv
# I am done with file number 302
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017161365.1_ASM1716136v1_genomic_padloc.csv
# Oops, there is no brex in file 303
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009930795.1_ASM993079v1_genomic_padloc.csv
# I am done with file number 304
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015910365.1_ASM1591036v1_genomic_padloc.csv
# I am done with file number 305
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021399255.1_ASM2139925v1_genomic_padloc.csv
# I am done with file number 306
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023311895.1_ASM2331189v1_genomic_padloc.csv
# Oops, there is no brex in file 307
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016952595.1_ASM1695259v1_genomic_padloc.csv
# I am done with file number 308
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007859675.1_ASM785967v1_genomic_padloc.csv
# I am done with file number 309
# I am done with file number 309
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013462275.1_ASM1346227v1_genomic_padloc.csv
# I am done with file number 310
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015052805.1_ASM1505280v1_genomic_padloc.csv
# I am done with file number 311
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022760275.1_ASM2276027v1_genomic_padloc.csv
# I am done with file number 312
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002327145.1_ASM232714v1_genomic_padloc.csv
# I am done with file number 313
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011045815.1_ASM1104581v1_genomic_padloc.csv
# I am done with file number 314
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013267235.1_ASM1326723v1_genomic_padloc.csv
# I am done with file number 315
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002813675.1_ASM281367v1_genomic_padloc.csv
# I am done with file number 316
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001623605.1_ASM162360v1_genomic_padloc.csv
# I am done with file number 317
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023735215.1_ASM2373521v1_genomic_padloc.csv
# I am done with file number 318
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_012974285.1_ASM1297428v1_genomic_padloc.csv
# I am done with file number 319
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004324145.2_ASM432414v2_genomic_padloc.csv
# I am done with file number 320
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009933525.1_ASM993352v1_genomic_padloc.csv
# Oops, there is no brex in file 321
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003020745.1_ASM302074v1_genomic_padloc.csv
# I am done with file number 322
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002943545.1_ASM294354v1_genomic_padloc.csv
# Oops, there is no brex in file 323
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_907163175.1_AUSMDU00004549_genomic_padloc.csv
# I am done with file number 324
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013085505.1_ASM1308550v1_genomic_padloc.csv
# Oops, there is no brex in file 325
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013462495.1_ASM1346249v1_genomic_padloc.csv
# I am done with file number 326
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000022205.1_ASM2220v1_genomic_padloc.csv
# I am done with file number 327
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020510545.1_ASM2051054v1_genomic_padloc.csv
# I am done with file number 328
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_907165365.1_USZ_VRE32_P32_hybrid_assembly_genomic_padloc.csv
# I am done with file number 329
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021545335.1_ASM2154533v1_genomic_padloc.csv
# I am done with file number 330
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002072735.1_ASM207273v1_genomic_padloc.csv
# Oops, there is no brex in file 331
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011106855.1_ASM1110685v1_genomic_padloc.csv
# Oops, there is no brex in file 332
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004324035.2_ASM432403v2_genomic_padloc.csv
# I am done with file number 333
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013256255.1_ASM1325625v1_genomic_padloc.csv
# I am done with file number 334
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022343145.1_ASM2234314v1_genomic_padloc.csv
# Oops, there is no brex in file 335
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003856815.1_ASM385681v1_genomic_padloc.csv
# I am done with file number 336
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001663715.1_ASM166371v1_genomic_padloc.csv
# Oops, there is no brex in file 337
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002290285.1_ASM229028v1_genomic_padloc.csv
# I am done with file number 338
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021399095.1_ASM2139909v1_genomic_padloc.csv
# I am done with file number 339
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021441825.1_ASM2144182v1_genomic_padloc.csv
# Oops, there is no brex in file 340
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013456995.1_ASM1345699v1_genomic_padloc.csv
# Oops, there is no brex in file 341
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002838305.1_ASM283830v1_genomic_padloc.csv
# I am done with file number 342
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011064245.1_ASM1106424v1_genomic_padloc.csv
# I am done with file number 343
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023735155.1_ASM2373515v1_genomic_padloc.csv
# I am done with file number 344
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001611795.1_ASM161179v1_genomic_padloc.csv
# Oops, there is no brex in file 345
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001518935.2_ASM151893v2_genomic_padloc.csv
# I am done with file number 346
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004777465.1_ASM477746v1_genomic_padloc.csv
# Oops, there is no brex in file 347
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013606065.1_ASM1360606v1_genomic_padloc.csv
# I am done with file number 348
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_011493005.1_ASM1149300v1_genomic_padloc.csv
# I am done with file number 349
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022870585.1_ASM2287058v1_genomic_padloc.csv
# I am done with file number 350
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_907163105.1_CB-03_assembly_genomic_padloc.csv
# I am done with file number 351
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900635415.1_E6043_hybrid_assembly_genomic_padloc.csv
# I am done with file number 352
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019552125.1_ASM1955212v1_genomic_padloc.csv
# Oops, there is no brex in file 353
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003288295.1_ASM328829v1_genomic_padloc.csv
# I am done with file number 354
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022591895.1_ASM2259189v1_genomic_padloc.csv
# I am done with file number 355
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016775685.1_ASM1677568v1_genomic_padloc.csv
# Oops, there is no brex in file 356
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022827545.1_ASM2282754v1_genomic_padloc.csv
# Oops, there is no brex in file 357
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020887095.1_ASM2088709v1_genomic_padloc.csv
# Oops, there is no brex in file 358
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000012865.1_ASM1286v1_genomic_padloc.csv
# I am done with file number 359
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015654185.1_ASM1565418v1_genomic_padloc.csv
# I am done with file number 360
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009676625.1_ASM967662v1_genomic_padloc.csv
# I am done with file number 361
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900343095.1_PRJEB25867_genomic_padloc.csv
# I am done with file number 362
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013393905.1_ASM1339390v1_genomic_padloc.csv
# I am done with file number 363
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014041915.1_ASM1404191v1_genomic_padloc.csv
# Oops, there is no brex in file 364
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020550085.1_ASM2055008v1_genomic_padloc.csv
# I am done with file number 365
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019048885.1_ASM1904888v1_genomic_padloc.csv
# I am done with file number 366
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001043175.1_ASM104317v1_genomic_padloc.csv
# I am done with file number 367
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000724485.1_ASM72448v1_genomic_padloc.csv
# I am done with file number 368
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022494135.1_ASM2249413v1_genomic_padloc.csv
# I am done with file number 369
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004295385.1_ASM429538v1_genomic_padloc.csv
# I am done with file number 370
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004324135.2_ASM432413v2_genomic_padloc.csv
# I am done with file number 371
# ...
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_006757745.1_ASM675774v1_genomic_padloc.csv
# I am done with file number 1534
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016925315.1_ASM1692531v1_genomic_padloc.csv
# I am done with file number 1535
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000009985.1_ASM998v1_genomic_padloc.csv
# I am done with file number 1536
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009217765.1_ASM921776v1_genomic_padloc.csv
# I am done with file number 1537
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001314325.1_ASM131432v1_genomic_padloc.csv
# Oops, there is no brex in file 1538
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000195755.1_ASM19575v1_genomic_padloc.csv
# I am done with file number 1539
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016403975.2_ASM1640397v2_genomic_padloc.csv
# I am done with file number 1540
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003367905.1_ASM336790v1_genomic_padloc.csv
# I am done with file number 1541
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000632415.1_ASM63241v1_genomic_padloc.csv
# I am done with file number 1542
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020271765.1_ASM2027176v1_genomic_padloc.csv
# I am done with file number 1543
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019551735.1_ASM1955173v1_genomic_padloc.csv
# I am done with file number 1544
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_008087665.1_ASM808766v1_genomic_padloc.csv
# I am done with file number 1545
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001263175.1_ASM126317v1_genomic_padloc.csv
# Oops, there is no brex in file 1546
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021018745.1_ASM2101874v1_genomic_padloc.csv
# Oops, there is no brex in file 1547
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003204955.1_ASM320495v1_genomic_padloc.csv
# I am done with file number 1548
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000477035.2_ASM47703v2_genomic_padloc.csv
# I am done with file number 1549
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002082015.1_ASM208201v1_genomic_padloc.csv
# I am done with file number 1550
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002970935.1_ASM297093v1_genomic_padloc.csv
# Oops, there is no brex in file 1551
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007993755.1_ASM799375v1_genomic_padloc.csv
# Oops, there is no brex in file 1552
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000832865.1_ASM83286v1_genomic_padloc.csv
# I am done with file number 1553
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021173085.1_ASM2117308v1_genomic_padloc.csv
# I am done with file number 1554
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019704235.1_ASM1970423v1_genomic_padloc.csv
# I am done with file number 1555
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900186865.1_49243_F02_genomic_padloc.csv
# I am done with file number 1556
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009664635.1_ASM966463v1_genomic_padloc.csv
# I am done with file number 1557
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_012050025.1_ASM1205002v1_genomic_padloc.csv
# I am done with file number 1558
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017638905.1_ASM1763890v1_genomic_padloc.csv
# I am done with file number 1559
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019552045.1_ASM1955204v1_genomic_padloc.csv
# Oops, there is no brex in file 1560
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015910265.1_ASM1591026v1_genomic_padloc.csv
# I am done with file number 1561
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000025725.1_ASM2572v1_genomic_padloc.csv
# I am done with file number 1562
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004730965.1_ASM473096v1_genomic_padloc.csv
# Oops, there is no brex in file 1563
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020221655.1_ASM2022165v1_genomic_padloc.csv
# I am done with file number 1564
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007833615.1_ASM783361v1_genomic_padloc.csv
# Oops, there is no brex in file 1565
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016695385.1_ASM1669538v1_genomic_padloc.csv
# Oops, there is no brex in file 1566
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000016785.1_ASM1678v1_genomic_padloc.csv
# I am done with file number 1567
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000299335.2_ASM29933v2_genomic_padloc.csv
# I am done with file number 1568
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019056615.1_ASM1905661v1_genomic_padloc.csv
# I am done with file number 1569
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009676605.1_ASM967660v1_genomic_padloc.csv
# I am done with file number 1570
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000829055.1_ASM82905v1_genomic_padloc.csv
# I am done with file number 1571
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019704255.1_ASM1970425v1_genomic_padloc.csv
# I am done with file number 1572
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013791465.1_ASM1379146v1_genomic_padloc.csv
# I am done with file number 1573
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015732575.1_S520_genomic_padloc.csv
# I am done with file number 1574
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002113825.1_ASM211382v1_genomic_padloc.csv
# I am done with file number 1575
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007970805.1_ASM797080v1_genomic_padloc.csv
# I am done with file number 1576
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002211985.1_ASM221198v1_genomic_padloc.csv
# I am done with file number 1577
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004519465.1_ASM451946v1_genomic_padloc.csv
# Oops, there is no brex in file 1578
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007993775.1_ASM799377v1_genomic_padloc.csv
# I am done with file number 1579
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014892695.1_ASM1489269v1_genomic_padloc.csv
# I am done with file number 1580
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017948345.1_ASM1794834v1_genomic_padloc.csv
# I am done with file number 1581
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014169335.1_ASM1416933v1_genomic_padloc.csv
# I am done with file number 1582
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019857425.1_ASM1985742v1_genomic_padloc.csv
# Oops, there is no brex in file 1583
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022964795.1_ASM2296479v1_genomic_padloc.csv
# I am done with file number 1584
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900639365.1_E7171_hybrid_assembly_genomic_padloc.csv
# I am done with file number 1585
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_008298035.1_ASM829803v1_genomic_padloc.csv
# I am done with file number 1586
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002887555.1_ASM288755v1_genomic_padloc.csv
# I am done with file number 1587
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020535225.1_ASM2053522v1_genomic_padloc.csv
# I am done with file number 1588
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900478755.1_32473_C02_genomic_padloc.csv
# I am done with file number 1589
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017377395.1_ASM1737739v1_genomic_padloc.csv
# I am done with file number 1590
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022592015.1_ASM2259201v1_genomic_padloc.csv
# I am done with file number 1591
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_900187185.1_50618_E01_genomic_padloc.csv
# I am done with file number 1592
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009176625.1_ASM917662v1_genomic_padloc.csv
# Oops, there is no brex in file 1593
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019930645.1_ASM1993064v1_genomic_padloc.csv
# I am done with file number 1594
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002970915.1_ASM297091v1_genomic_padloc.csv
# Oops, there is no brex in file 1595
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023330785.1_ASM2333078v1_genomic_padloc.csv
# I am done with file number 1596
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007874125.1_ASM787412v1_genomic_padloc.csv
# I am done with file number 1597
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019702905.1_ASM1970290v1_genomic_padloc.csv
# I am done with file number 1598
# I am done with file number 1598
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003072645.1_ASM307264v1_genomic_padloc.csv
# Oops, there is no brex in file 1599
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014169595.1_ASM1416959v1_genomic_padloc.csv
# I am done with file number 1600
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_018409545.1_ASM1840954v1_genomic_padloc.csv
# Oops, there is no brex in file 1601
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002968935.1_ASM296893v1_genomic_padloc.csv
# I am done with file number 1602
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003344865.1_ASM334486v1_genomic_padloc.csv
# Oops, there is no brex in file 1603
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002224645.1_ASM222464v1_genomic_padloc.csv
# Oops, there is no brex in file 1604
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_009866925.2_ASM986692v3_genomic_padloc.csv
# I am done with file number 1605
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_021952745.1_ASM2195274v1_genomic_padloc.csv
# I am done with file number 1606
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003186565.1_ASM318656v1_genomic_padloc.csv
# I am done with file number 1607
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016415545.1_ASM1641554v1_genomic_padloc.csv
# I am done with file number 1608
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022631235.1_ASM2263123v1_genomic_padloc.csv
# I am done with file number 1609
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016801775.1_ASM1680177v1_genomic_padloc.csv
# I am done with file number 1610
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013343215.1_ASM1334321v1_genomic_padloc.csv
# I am done with file number 1611
# I am done with file number 1611
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_010729895.1_ASM1072989v1_genomic_padloc.csv
# I am done with file number 1612
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020990405.1_ASM2099040v1_genomic_padloc.csv
# I am done with file number 1613
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013307125.1_ASM1330712v1_genomic_padloc.csv
# I am done with file number 1614
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000017565.1_ASM1756v1_genomic_padloc.csv
# I am done with file number 1615
# I am done with file number 1615
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004324245.2_ASM432424v2_genomic_padloc.csv
# I am done with file number 1616
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_006494815.1_ASM649481v1_genomic_padloc.csv
# I am done with file number 1617
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003119115.1_ASM311911v1_genomic_padloc.csv
# Oops, there is no brex in file 1618
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023546885.1_ASM2354688v1_genomic_padloc.csv
# I am done with file number 1619
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001747425.1_ASM174742v1_genomic_padloc.csv
# I am done with file number 1620
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004322855.1_ASM432285v1_genomic_padloc.csv
# I am done with file number 1621
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002903005.1_ASM290300v1_genomic_padloc.csv
# I am done with file number 1622
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002209245.2_ASM220924v2_genomic_padloc.csv
# I am done with file number 1623
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_014295035.1_ASM1429503v1_genomic_padloc.csv
# I am done with file number 1624
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002079305.1_ASM207930v1_genomic_padloc.csv
# Oops, there is no brex in file 1625
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013207105.1_ASM1320710v1_genomic_padloc.csv
# I am done with file number 1626
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003966445.1_ASM396644v1_genomic_padloc.csv
# I am done with file number 1627
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_904830975.1_L3_CS7_E2980_genomic_padloc.csv
# I am done with file number 1628
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_017724195.1_ASM1772419v1_genomic_padloc.csv
# I am done with file number 1629
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002196475.1_ASM219647v1_genomic_padloc.csv
# I am done with file number 1630
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016756195.1_ASM1675619v1_genomic_padloc.csv
# I am done with file number 1631
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023735295.1_ASM2373529v1_genomic_padloc.csv
# I am done with file number 1632
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_010919095.1_ASM1091909v1_genomic_padloc.csv
# Oops, there is no brex in file 1633
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016755995.1_ASM1675599v1_genomic_padloc.csv
# I am done with file number 1634
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_015767595.1_ASM1576759v1_genomic_padloc.csv
# I am done with file number 1635
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001442755.1_ASM144275v1_genomic_padloc.csv
# I am done with file number 1636
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023703955.1_ASM2370395v1_genomic_padloc.csv
# I am done with file number 1637
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000213235.1_ASM21323v1_genomic_padloc.csv
# I am done with file number 1638
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_023703795.1_ASM2370379v1_genomic_padloc.csv
# I am done with file number 1639
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019739075.1_ASM1973907v1_genomic_padloc.csv
# I am done with file number 1640
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022691685.1_ASM2269168v1_genomic_padloc.csv
# I am done with file number 1641
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_001577465.1_ASM157746v1_genomic_padloc.csv
# I am done with file number 1642
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_007833275.1_ASM783327v1_genomic_padloc.csv
# I am done with file number 1643
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004104505.1_ASM410450v1_genomic_padloc.csv
# Oops, there is no brex in file 1644
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016904795.1_ASM1690479v2_genomic_padloc.csv
# I am done with file number 1645
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000253275.1_ASM25327v1_genomic_padloc.csv
# Oops, there is no brex in file 1646
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_022557195.1_ASM2255719v1_genomic_padloc.csv
# I am done with file number 1647
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_002896855.1_ASM289685v1_genomic_padloc.csv
# Oops, there is no brex in file 1648
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_020844125.1_ASM2084412v1_genomic_padloc.csv
# Oops, there is no brex in file 1649
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_003342675.1_ASM334267v1_genomic_padloc.csv
# I am done with file number 1650
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_016889825.1_ASM1688982v1_genomic_padloc.csv
# I am done with file number 1651
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_019704175.1_ASM1970417v1_genomic_padloc.csv
# I am done with file number 1652
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_006351805.1_ASM635180v1_genomic_padloc.csv
# I am done with file number 1653
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_004011075.1_ASM401107v1_genomic_padloc.csv
# I am done with file number 1654
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_000284515.1_ASM28451v1_genomic_padloc.csv
# I am done with file number 1655
# ./2024-02-26_padloc_hmm_custom/padloc_hmm_custom/GCF_013389595.1_ASM1338959v1_genomic_padloc.csv
# I am done with file number 1656

# %%
for i in error:
    with open("errors_genomes.txt", 'a') as file:
        file.write(f'{i}\n')
